# %% [markdown]
# # Happiness Survey Analysis Pipeline
#
# This notebook runs the end-to-end pipeline for processing and analyzing the FPT Polytechnic student happiness survey data.

# %% [markdown]
# ## 1. Imports and Setup
#
# First, we import the necessary libraries and add the `src` directory to the system path to locate our custom modules.

# %%
import os
import sys
from pathlib import Path

# Resolve project root for cross-platform, device-independent paths
_cwd = Path.cwd()
if (_cwd / "main.ipynb").exists():
    PROJECT_ROOT = _cwd.parent
    SRC_ROOT = _cwd
elif (_cwd / "src" / "main.ipynb").exists():
    PROJECT_ROOT = _cwd
    SRC_ROOT = _cwd / "src"
else:
    PROJECT_ROOT = _cwd
    SRC_ROOT = _cwd

# Ensure paths for imports: src for etl/analytics, project root for src.config
for p in (str(SRC_ROOT), str(PROJECT_ROOT)):
    if p not in sys.path:
        sys.path.insert(0, p)

from etl.processor import DataProcessor
from analytics.analyzer import DataAnalyzer

# %% [markdown]
# ## 2. Run ETL Process
#
# This step loads the raw data, cleans it, applies transformations (like renaming columns and converting data types), and saves the processed data to the `data/processed` directory.

# %%
# --- ETL Step ---
print("--- Starting ETL Process ---")

# Define file paths (Path objects work on Windows, macOS, Linux)
raw_data_path = PROJECT_ROOT / 'data' / 'raw' / 'fpoly_survey.csv'
processed_data_path = PROJECT_ROOT / 'data' / 'processed' / 'fpoly_survey_processed.csv'

if not raw_data_path.exists():
    print(f"ERROR: Raw data file not found at {raw_data_path}")
else:
    # Instantiate the processor and run the ETL process
    data_processor = DataProcessor(file_path=raw_data_path)
    # The 'process' method will load, clean, transform, and save the data.
    processed_df_head = data_processor.process(output_path=processed_data_path)
    print("--- ETL Process Finished ---")
    print("Dữ liệu xem trước 👀:")
    display(processed_df_head)
# Out:
# --- Starting ETL Process ---
# Loading data...
# Renaming columns...
# Cleaning data...
# 🚀 Khởi động quy trình ETL...
# 🔄 Đã đảo ngược điểm cho cột: aca_deadline_pressure
# 🔄 Đã đảo ngược điểm cho cột: fin_living_cost_worry
# ✅ Hoàn tất ETL. Dữ liệu sạch sẵn sàng: 124 dòng.
# 📂 Đang chuẩn bị lưu dữ liệu vào: c:\Users\OMEN\Desktop\Learn\FPT\Working_skill\data\processed\fpoly_survey_processed.csv...
# ✅ Lưu dữ liệu thành công.
# --- ETL Process Finished ---
# Dữ liệu xem trước 👀:
# c:\Users\OMEN\Desktop\Learn\FPT\Working_skill\src\etl\processor.py:59: UserWarning: Parsing dates in %d/%m/%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   self.data['timestamp'] = pd.to_datetime(self.data['timestamp'], errors='coerce')
#             timestamp                  dem_major  dem_semester  dem_gpa  \
# 0 2026-01-20 10:01:33  Ngành Công Nghệ Thông Tin             5      8.5
# 1 2026-01-20 10:14:55            Thiết kế đồ họa             5      8.5
# 3 2026-01-20 11:41:38  Ngành Công Nghệ Thông Tin             5      7.5
# 4 2026-01-20 11:42:55                       Khác             5      8.5
# 6 2026-01-20 12:37:46  Ngành Công Nghệ Thông Tin             5      9.5
#
#     dem_residence  hap_general_satisfaction  hap_school_energy  \
# 0  Ở với gia đình                         4                  3
# 1             KTX                         4                  2
# 3           Ở trọ                         3                  4
# 4  Ở với gia đình                         4                  4
# 6  Ở với gia đình                         5                  5
#
#    hap_meaningful_life  hap_loyalty_choice  aca_curriculum_fit  ...  \
# 0                    4                   4                   4  ...
# 1                    2                   1                   3  ...
# 3                    3                   3                   3  ...
# 4                    5                   5                   5  ...
# 6                    4                   4                   3  ...
#
#    env_utilities  env_dynamic_culture  soc_friendship_support  \
# 0              3                    4                       5
# 1              3                    4                       3
# 3              3                    3                       4
# 4              3                    4                       5
# 6              4                    4                       4
#
#    soc_activity_integration  soc_family_support  fin_tuition_value  \
# 0                         3                   4                  3
# 1                         2                   4                  3
# 3                         3                   4                  3
# 4                         2                   5                  2
# 6                         3                   5                  4
#
#    fin_living_cost_worry  fin_job_prospects  \
# 0                      2                  3
# 1                      3                  1
# 3                      1                  3
# 4                      2                  3
# 6                      3                  4
#
#                                                 wish  Column 27
# 0                                                NaN        NaN
# 1  trường bớt drama lại. ngoại trừ việc dạy kiến ...        NaN
# 3                                                NaN        NaN
# 4  Trường siết chặt hơn về đánh giá năng lực của ...        NaN
# 6  Có nhiều cuộc thi hơn cho ngành cntt nói chung...        NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 3. Run Analysis
#
# Now that we have clean data, this step runs the various analyses defined in the `DataAnalyzer` class and prints the final report.

# %%
# --- Analysis Step ---
import pprint


print("--- Starting Analysis Process ---")

if not processed_data_path.exists():
    print(f"ERROR: Processed data file not found at {processed_data_path}")
else:
    # Instantiate the analyzer with the processed data
    data_analyzer = DataAnalyzer(file_path=processed_data_path)

    # Run the analysis
    analysis_report = data_analyzer.analysis()

    # Print the final report
    print("--- Analysis Report ---")
    pprint.pprint(analysis_report)
    print("--- Analysis Finished ---")
# Out:
# --- Starting Analysis Process ---
# 📊 Đang phân tích các chỉ số hạnh phúc...
# ✅ Phân tích hoàn tất.
# --- Analysis Report ---
# {'ahs_overall': np.float64(3.7),
#  'correlations': {'Academic': np.float64(0.6),
#                   'Environment': np.float64(0.55),
#                   'Finance': np.float64(0.68),
#                   'Social': np.float64(0.54)},
#  'factor_scores': {'Academic (X1)': np.float64(3.32),
#                    'Environment (X2)': np.float64(3.72),
#                    'Finance (X4)': np.float64(3.37),
#                    'Social (X3)': np.float64(3.86)},
#  'gpa_happiness_correlation': {'5.0-6.5': 3.57,
#                                '6.5-8.0': 3.7,
#                                '<5.0': 3.25,
#                                '>8.0': 3.76},
#  'nhs_percentage': 40.32,
#  'residence_stress_index': {'KTX': 2.62,
#                             'Nhà riêng': 2.5,
#                             'Ở trọ': 2.28,
#                             'Ở với gia đình': 2.84},
#  'retention_risk_rate': 13.71,
#  'semester_happiness_curve': {1: 3.5,
#                               2: 3.91,
#                               3: 4.0,
#                               4: 4.06,
#                               5: 3.5,
#                               6: 3.56,
#                               8: 2.83},
#  'top_correlated_factor': 'Finance',
#  'wish_analysis': {'có': 40, 'hơn': 39, 'nhiều': 25, 'và': 22, 'được': 18}}
# --- Analysis Finished ---
